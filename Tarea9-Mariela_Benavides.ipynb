# %% [markdown]
# # Ejercicios de pandas

# %% [markdown]
# ***

# %%
import pandas as pd
import numpy as np
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ## Ejercicio 1
#
# 1. Generar arreglos de numpy para obtener el resultado de $ z = f(x,y) $ para un conjunto de entrada aleatorio de al menos 100 filas.
#
# - Crear un `DataFrame` de pandas con las columnas $x$, $y$ y $z$.
# - Obtener el promedio de cada `Series` en el `DataFrame`.

# %%
X=np.random.random(100)*10
Y=np.random.random(100)*10

# %%
f=lambda X,Y: 2*X+5*Y

# %%
Z= f(X,Y)

# %%
df = pd.DataFrame({'X': X, 'Y': Y, 'Z':Z })
df
# Out:
#            X         Y          Z
# 0   6.273882  7.471569  49.905612
# 1   5.277906  9.544933  58.280477
# 2   2.348964  4.065916  25.027510
# 3   9.456168  1.887755  28.351113
# 4   6.491561  3.432984  30.148042
# ..       ...       ...        ...
# 95  3.523734  3.589312  24.994027
# 96  9.001561  5.775843  46.882335
# 97  8.058838  5.058507  41.410208
# 98  0.243077  3.068697  15.829639
# 99  0.104505  3.145245  15.935234
#
# [100 rows x 3 columns]

# %%
df.mean()
# Out:
# X     5.112115
# Y     5.639998
# Z    38.424222
# dtype: float64

# %% [markdown]
# ## Ejercicio 1.1
#
# De forma similar al ejercicio anterior, genere un `DataFrame` con los resultados de una función $y = f(x)$ con al menos 100 filas.
#
# - Grafique los resultados con `matplotlib` utilizando 2 variantes:
#
#     - a. Utilizando los arreglos de numpy (objetos `ndarray`) que utilizó para generar el `DataFrame`.
#     - b. Utilizando los objetos `Series` del `DataFrame`.
#
# - Obtenga el objeto *handler* de la gráfica y guarde la gráfica en PDF.
#
# - Asegúrese de entender la diferencia entre generar la gráfica para guardarla (sin mostrarla) y generar la gráfica para mostrarla.

# %%
x=np.random.random(100)*10
f=lambda X: X**2
y=f(x)

# %%
df = pd.DataFrame({'x': x, 'y': y })
df
# Out:
#            x          y
# 0   0.651684   0.424692
# 1   0.966460   0.934046
# 2   7.143435  51.028670
# 3   4.696855  22.060444
# 4   2.892153   8.364552
# ..       ...        ...
# 95  1.178974   1.389980
# 96  6.147035  37.786038
# 97  5.886618  34.652271
# 98  3.759115  14.130943
# 99  8.999855  80.997395
#
# [100 rows x 2 columns]

# %%
plt.figure(figsize=(8, 6))
plt.plot(x, y, 'o',color="orange")
plt.xlabel('x')
plt.ylabel('y')
plt.title("Plot of $y=x^2$")

plt.savefig("grafiquiña.pdf",format='pdf')
plt.show()

# %%
m=df.plot.scatter(x='x',y ='y',color='m')
m

# %%
m.get_figure().savefig('grafiquita2.pdf',dpi=80)

# %% [markdown]
# ## Ejercicio 2
#
# 1. Prueba 5 funciones de la primera página del *cheat sheet* no vistas en la exposición.

# %%
df2 = pd.read_csv("data/titanic.csv")

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# **Ejemplos de funciones**

# %%
df.sort_values('Age',ascending=False) #ordena los valores en la columna seleccionada
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 630          631         1       1      Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                       Svensson, Mr. Johan
# 493          494         0       1                   Artagaveytia, Mr. Ramon
# 96            97         0       1                 Goldschmidt, Mr. George B
# 116          117         0       3                      Connors, Mr. Patrick
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 630    male  80.0      0      0       27042  30.0000   A23        S
# 851    male  74.0      0      0      347060   7.7750   NaN        S
# 493    male  71.0      0      0    PC 17609  49.5042   NaN        C
# 96     male  71.0      0      0    PC 17754  34.6542    A5        C
# 116    male  70.5      0      0      370369   7.7500   NaN        Q
# ..      ...   ...    ...    ...         ...      ...   ...      ...
# 859    male   NaN      0      0        2629   7.2292   NaN        C
# 863  female   NaN      8      2    CA. 2343  69.5500   NaN        S
# 868    male   NaN      0      0      345777   9.5000   NaN        S
# 878    male   NaN      0      0      349217   7.8958   NaN        S
# 888  female   NaN      1      2  W./C. 6607  23.4500   NaN        S
#
# [891 rows x 12 columns]

# %%
df.rename(columns={'Sex':'Gender'}) #Modifica el titulo de la columna seleccionada
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.shift(1)#Agrega filas en la posición indicada
# Out:
#      PassengerId  Survived  Pclass  \
# 0            NaN       NaN     NaN
# 1            1.0       0.0     3.0
# 2            2.0       1.0     1.0
# 3            3.0       1.0     3.0
# 4            4.0       1.0     1.0
# ..           ...       ...     ...
# 886        886.0       0.0     3.0
# 887        887.0       0.0     2.0
# 888        888.0       1.0     1.0
# 889        889.0       0.0     3.0
# 890        890.0       1.0     1.0
#
#                                                   Name     Sex   Age  SibSp  \
# 0                                                  NaN     NaN   NaN    NaN
# 1                              Braund, Mr. Owen Harris    male  22.0    1.0
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 3                               Heikkinen, Miss. Laina  female  26.0    0.0
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# ..                                                 ...     ...   ...    ...
# 886               Rice, Mrs. William (Margaret Norton)  female  39.0    0.0
# 887                              Montvila, Rev. Juozas    male  27.0    0.0
# 888                       Graham, Miss. Margaret Edith  female  19.0    0.0
# 889           Johnston, Miss. Catherine Helen "Carrie"  female   NaN    1.0
# 890                              Behr, Mr. Karl Howell    male  26.0    0.0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0      NaN               NaN      NaN   NaN      NaN
# 1      0.0         A/5 21171   7.2500   NaN        S
# 2      0.0          PC 17599  71.2833   C85        C
# 3      0.0  STON/O2. 3101282   7.9250   NaN        S
# 4      0.0            113803  53.1000  C123        S
# ..     ...               ...      ...   ...      ...
# 886    5.0            382652  29.1250   NaN        Q
# 887    0.0            211536  13.0000   NaN        S
# 888    0.0            112053  30.0000   B42        S
# 889    2.0        W./C. 6607  23.4500   NaN        S
# 890    0.0            111369  30.0000  C148        C
#
# [891 rows x 12 columns]

# %%
df['Pclass'].nunique()#Indica el número de valores únicos en los datos
# Out:
# 3

# %%
df.groupby('Sex').var()#Ordena por sexo y luego calcula la varianza de los datos
# Out:
#          PassengerId  Survived    Pclass         Age     SibSp     Parch  \
# Sex
# female  65970.034320  0.192029  0.734946  199.096233  1.337539  1.046214
# male    66299.111942  0.153488  0.661913  215.449579  1.127443  0.374904
#
#                Fare
# Sex
# female  3363.732930
# male    1860.909702

# %% [markdown]
# ## Ejercicio 3
#
# Resuelva las siguientes preguntas utilizando las funciones de pandas. Ayúdese con la hoja de trucos.

# %%
df = pd.read_csv("data/titanic.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
#  - ¿Cuál es la tarifa máxima que se pagó? ¿Y la mediana?

# %%
df['Fare'].max()#Se calcula la tarifa máxima
# Out:
# 512.3292

# %%
df['Fare'].median()#Se calcula la mediana
# Out:
# 14.4542

# %% [markdown]
# - Calcule la tasa de supervivencia promedio para todos los pasajeros (nota: la columna `Survived` indica si alguien sobrevivió (1) o no (0)).

# %%
(df['Survived'].sum())/(df['Survived'].count())
# Out:
# 0.3838383838383838

# %% [markdown]
# - Haga una gráfica de la distribución de edades de los pasajeros del Titanic

# %%
df['Age'].plot.hist(color="darkred",bins=12)

# %% [markdown]
# - Según el conjunto de datos del Titanic, seleccione todas las filas para pasajeros masculinos y calcule la edad media de esos pasajeros. Haz lo mismo para las pasajeras.

# %%
e= df[df['Sex'] == 'male' ]
e
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    22.0      1      0         A/5 21171   7.2500   NaN        S
# 4    35.0      0      0            373450   8.0500   NaN        S
# 5     NaN      0      0            330877   8.4583   NaN        Q
# 6    54.0      0      0             17463  51.8625   E46        S
# 7     2.0      3      1            349909  21.0750   NaN        S
# ..    ...    ...    ...               ...      ...   ...      ...
# 883  28.0      0      0  C.A./SOTON 34068  10.5000   NaN        S
# 884  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 886  27.0      0      0            211536  13.0000   NaN        S
# 889  26.0      0      0            111369  30.0000  C148        C
# 890  32.0      0      0            370376   7.7500   NaN        Q
#
# [577 rows x 12 columns]

# %%
e['Age'].mean()
# Out:
# 30.72664459161148

# %%
df[df['Sex'] == 'female' ]['Age'].mean()
# Out:
# 27.915708812260537

# %% [markdown]
# - Según el conjunto de datos del Titanic, ¿cuántos pasajeros mayores de 70 estaban en el Titanic?

# %%
(df[df['Age']>70 ])['Age'].count()
# Out:
# 5

# %% [markdown]
# - Calcula la edad promedio para cada sexo. Ahora utiliza el método `groupby`.

# %%
df.groupby(by='Sex')['Age'].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %% [markdown]
# - Calcule esta relación de supervivencia para todos los pasajeros menores de 25 años (recuerde: filtrado / indexación booleana).

# %%
ed=(df[df['Age']<25 ])
(ed['Survived'].sum())/(ed['Survived'].count())
# Out:
# 0.4244604316546763

# %% [markdown]
# - ¿Cuál es la diferencia en la proporción de supervivencia entre sexos?

# %%
p=df.groupby(by='Sex')['Survived'].sum()/df.groupby(by='Sex')['Survived'].count()
p
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
p[0]-p[1]
# Out:
# 0.5531300709799203

# %% [markdown]
# - ¿O cómo difiere la proporción de sobrevivientes entre las diferentes clases de pasajeros? Haz una gráfica de barras visualizando la relación de supervivencia para las 3 clases.

# %%
cl=df.groupby(by='Pclass')['Survived'].sum()/df.groupby(by='Pclass')['Survived'].count()
cl
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
cl.plot(kind='bar',color='orange',width=0.85)

# %% [markdown]
# - Haga una gráfica de barras para visualizar la tarifa promedio pagada por los pasajeros de acuerdo a su edad. Para esto:
#     - Primero, separamos a los pasajeros por rango, utilizando la función `pd.cut` y agregamos esta serie al DataFrame.
#     - Debemos agrupar por esta columna y calcular el promedio de las tarifas.
#     - Por último, agregamos `plot(kind='bar')` para obtener la gráfica de barras.

# %%
df['AgeClass'] = pd.cut(df['Age'], bins=np.arange(0,90,10))

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked      AgeClass
# 0        0         A/5 21171   7.2500   NaN        S  (20.0, 30.0]
# 1        0          PC 17599  71.2833   C85        C  (30.0, 40.0]
# 2        0  STON/O2. 3101282   7.9250   NaN        S  (20.0, 30.0]
# 3        0            113803  53.1000  C123        S  (30.0, 40.0]
# 4        0            373450   8.0500   NaN        S  (30.0, 40.0]
# ..     ...               ...      ...   ...      ...           ...
# 886      0            211536  13.0000   NaN        S  (20.0, 30.0]
# 887      0            112053  30.0000   B42        S  (10.0, 20.0]
# 888      2        W./C. 6607  23.4500   NaN        S           NaN
# 889      0            111369  30.0000  C148        C  (20.0, 30.0]
# 890      0            370376   7.7500   NaN        Q  (30.0, 40.0]
#
# [891 rows x 13 columns]

# %%
G=df.groupby(by='AgeClass')['Fare'].mean()
G
# Out:
# AgeClass
# (0, 10]     30.434439
# (10, 20]    29.529531
# (20, 30]    28.306719
# (30, 40]    42.496100
# (40, 50]    41.163181
# (50, 60]    44.774802
# (60, 70]    45.910782
# (70, 80]    25.936680
# Name: Fare, dtype: float64

# %%
G.plot(kind='bar',color='green')
